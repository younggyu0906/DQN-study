# %%
import numpy as np
import tensorflow as tf
import random
import dqn
from collections import deque

import gym
env = gym.make('CartPole-v0')
env._max_episode_steps = 10000

# Constants defining our neural network
input_size = env.observation_space.shape[0]
output_size = env.action_space.n

mainDQN = None

dis = 0.9
REPLAY_MEMORY = 50000
# Out:
# [2017-11-15 14:09:03,038] Making new env: CartPole-v0

# %%
class DQN:
    def __init__(self, session, input_size, output_size, name="main"):
        self.session = session
        self.input_size = input_size
        self.output_size = output_size
        self.net_name = name
        
        self._build_network()
        
    def _build_network(self, h_size = 10, h2_size = 10, l_rate = 1e-1):
        with tf.variable_scope(self.net_name):
            self._X = tf.placeholder(
                tf.float32, [None, self.input_size], name = "input_x")
        
            # First layer of weights
            W1 = tf.get_variable("W1", shape=[self.input_size, h_size],
                             initializer=tf.contrib.layers.xavier_initializer())
            layer1 = tf.nn.tanh(tf.matmul(self._X, W1))
        
            # Second Layer of weights
            W2 = tf.get_variable("W2", shape=[h_size, h2_size],
                             initializer=tf.contrib.layers.xavier_initializer())
            layer2 = tf.nn.tanh(tf.matmul(layer1, W2))
            
            # Third Layer of weights
            W3 = tf.get_variable("W3", shape=[h2_size, self.output_size],
                             initializer=tf.contrib.layers.xavier_initializer())
        
            # Q prediction
            self._Qpred = tf.matmul(layer2, W3)
        
        # We need to define the parts of the network needed for learning a policy
        self._Y = tf.placeholder(
            shape = [None, self.output_size], dtype = tf.float32)
    
        # Loss function
        self._loss = tf.reduce_mean(tf.square(self._Y - self._Qpred))
        # Learning
        self._train = tf.train.AdamOptimizer(
            learning_rate=l_rate).minimize(self._loss)
    
    def predict(self, state):
        x = np.reshape(state, [1, self.input_size])
        return self.session.run(self._Qpred, feed_dict = {self._X: x})
    
    def update(self, x_stack, y_stack):
        return self.session.run([self._loss, self._train], feed_dict = 
                               {self._X: x_stack, self._Y: y_stack})

# %%
def replay_train(mainDQN, targetDQN, train_batch):
    x_stack = np.empty(0).reshape(0, input_size)
    y_stack = np.empty(0).reshape(0, output_size)
    
    # Get stored information from the buffer
    for state, action, reward, next_state, done in train_batch:
        Q = mainDQN.predict(state)
        
        # terminal?
        if done:
            Q[0, action] = reward
        else:
            # get target from target DQN (Q')
            Q[0, action] = reward + dis * np.max(targetDQN.predict(next_state))
            
        y_stack = np.vstack([y_stack, Q])
        x_stack = np.vstack([x_stack, state])
        
    # Train our network using target and predicted Q values on each episode
    return mainDQN.update(x_stack, y_stack)

# %%
def get_copy_var_ops(*, dest_scope_name = "target", src_scope_name = "main"):
    # Copy variables src_scope to dest_scope
    op_holder = []
    
    src_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope = src_scope_name)
    dest_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope = dest_scope_name)
    
    for src_var, dest_var in zip(src_vars, dest_vars):
        op_holder.append(dest_var.assign(src_var.value()))
        
    return op_holder

# %%
def bot_play(mainDQN):
    # See our trained network in action
    s = env.reset()
    reward_sum = 0
    while True:
        env.render()
        a = np.argmax(mainDQN.predict(s))
        s, reward, done, _ = env.step(a)
        reward_sum += reward
        if done:
            print("Total score: {}".format(reward_sum))
            break

# %%
def main():
    max_episodes = 1000
    # store the previous observations in replay memory
    replay_buffer = deque()
    
    with tf.Session() as sess:
        mainDQN = DQN(sess, input_size, output_size, name = "main")
        targetDQN = DQN(sess, input_size, output_size, name = "target")
        tf.global_variables_initializer().run()
    
        # initial copy q_net -> target_net
        copy_ops = get_copy_var_ops(dest_scope_name = "target", src_scope_name = "main")
    
        sess.run(copy_ops)
    
        for episode in range(max_episodes):
            e = 1. / ((episode / 10) + 1)
            done = False
            step_count = 0
            state = env.reset()
        
            while not done:
                if np.random.rand(1) < e:
                    action = env.action_space.sample()
                else:
                    # Choose an action by greedily from the Q-netsork
                    action = np.argmax(mainDQN.predict(state))
                
                # Get new state and reward from environment
                next_state, reward, done, _ = env.step(action)
                if done: # Penalty
                    reward = -100
                
                # Save the experience to our buffer
                replay_buffer.append((state, action, reward, next_state, done))
                if len(replay_buffer) > REPLAY_MEMORY:
                    replay_buffer.popleft()

                state = next_state
                step_count += 1
                if step_count > 1000: # Good enough. Let's move on
                    break

            print("Episode: {}  step:  {}".format(episode, step_count))
            if step_count > 1000:
                pass
                # break

            if episode % 10 == 1:  # train every 10 episode
                # Get a random batch of experiences.
                for _ in range(50):
                    minibatch = random.sample(replay_buffer, 10)
                    loss, _ = replay_train(mainDQN, targetDQN, minibatch)

                print("Loss: ", loss)
                #copy q_net -> target_net
                sess.run(copy_ops)

        bot_play(mainDQN)
            
if __name__ == "__main__":
    main()
# Out:
# Episode: 0  step:  15
# Episode: 1  step:  12
# Loss:  23.47
# Episode: 2  step:  13
# Episode: 3  step:  14
# Episode: 4  step:  14
# Episode: 5  step:  14
# Episode: 6  step:  11
# Episode: 7  step:  16
# Episode: 8  step:  9
# Episode: 9  step:  11
# Episode: 10  step:  14
# Episode: 11  step:  16
# Loss:  952.459
# Episode: 12  step:  51
# Episode: 13  step:  100
# Episode: 14  step:  27
# Episode: 15  step:  65
# Episode: 16  step:  71
# Episode: 17  step:  119
# Episode: 18  step:  54
# Episode: 19  step:  37
# Episode: 20  step:  69
# Episode: 21  step:  155
# Loss:  10.764
# Episode: 22  step:  134
# Episode: 23  step:  75
# Episode: 24  step:  133
# Episode: 25  step:  104
# Episode: 26  step:  94
# Episode: 27  step:  125
# Episode: 28  step:  71
# Episode: 29  step:  70
# Episode: 30  step:  143
# Episode: 31  step:  77
# Loss:  3.6998
# Episode: 32  step:  121
# Episode: 33  step:  51
# Episode: 34  step:  72
# Episode: 35  step:  59
# Episode: 36  step:  84
# Episode: 37  step:  76
# Episode: 38  step:  150
# Episode: 39  step:  48
# Episode: 40  step:  77
# Episode: 41  step:  78
# Loss:  1.20042
# Episode: 42  step:  47
# Episode: 43  step:  70
# Episode: 44  step:  72
# Episode: 45  step:  37
# Episode: 46  step:  55
# Episode: 47  step:  41
# Episode: 48  step:  91
# Episode: 49  step:  90
# Episode: 50  step:  45
# Episode: 51  step:  79
# Loss:  1.83246
# Episode: 52  step:  42
# Episode: 53  step:  70
# Episode: 54  step:  70
# Episode: 55  step:  52
# Episode: 56  step:  54
# Episode: 57  step:  73
# Episode: 58  step:  43
# Episode: 59  step:  35
# Episode: 60  step:  62
# Episode: 61  step:  70
# Loss:  0.526102
# Episode: 62  step:  9
# Episode: 63  step:  9
# Episode: 64  step:  8
# Episode: 65  step:  10
# Episode: 66  step:  10
# Episode: 67  step:  9
# Episode: 68  step:  8
# Episode: 69  step:  10
# Episode: 70  step:  9
# Episode: 71  step:  10
# Loss:  0.906778
# Episode: 72  step:  185
# Episode: 73  step:  259
# Episode: 74  step:  168
# Episode: 75  step:  142
# Episode: 76  step:  232
# Episode: 77  step:  191
# Episode: 78  step:  243
# Episode: 79  step:  194
# Episode: 80  step:  328
# Episode: 81  step:  165
# Loss:  1.2761
# Episode: 82  step:  12
# Episode: 83  step:  10
# Episode: 84  step:  10
# Episode: 85  step:  8
# Episode: 86  step:  10
# Episode: 87  step:  9
# Episode: 88  step:  8
# Episode: 89  step:  8
# Episode: 90  step:  12
# Episode: 91  step:  11
# Loss:  0.952967
# Episode: 92  step:  24
# Episode: 93  step:  9
# Episode: 94  step:  27
# Episode: 95  step:  53
# Episode: 96  step:  31
# Episode: 97  step:  55
# Episode: 98  step:  28
# Episode: 99  step:  34
# Episode: 100  step:  23
# Episode: 101  step:  46
# Loss:  3.20037
# Episode: 102  step:  106
# Episode: 103  step:  84
# Episode: 104  step:  82
# Episode: 105  step:  58
# Episode: 106  step:  69
# Episode: 107  step:  78
# Episode: 108  step:  66
# Episode: 109  step:  66
# Episode: 110  step:  69
# Episode: 111  step:  74
# Loss:  2.47038
# Episode: 112  step:  32
# Episode: 113  step:  28
# Episode: 114  step:  41
# Episode: 115  step:  27
# Episode: 116  step:  31
# Episode: 117  step:  41
# Episode: 118  step:  35
# Episode: 119  step:  34
# Episode: 120  step:  33
# Episode: 121  step:  24
# Loss:  2.62558
# Episode: 122  step:  10
# Episode: 123  step:  10
# Episode: 124  step:  10
# Episode: 125  step:  11
# Episode: 126  step:  27
# Episode: 127  step:  10
# Episode: 128  step:  10
# Episode: 129  step:  15
# Episode: 130  step:  10
# Episode: 131  step:  11
# Loss:  3.75854
# Episode: 132  step:  24
# Episode: 133  step:  40
# Episode: 134  step:  32
# Episode: 135  step:  71
# Episode: 136  step:  32
# Episode: 137  step:  34
# Episode: 138  step:  35
# Episode: 139  step:  29
# Episode: 140  step:  25
# Episode: 141  step:  35
# Loss:  4.31868
# Episode: 142  step:  24
# Episode: 143  step:  21
# Episode: 144  step:  26
# Episode: 145  step:  26
# Episode: 146  step:  20
# Episode: 147  step:  23
# Episode: 148  step:  40
# Episode: 149  step:  28
# Episode: 150  step:  34
# Episode: 151  step:  30
# Loss:  3.20579
# Episode: 152  step:  23
# Episode: 153  step:  20
# Episode: 154  step:  17
# Episode: 155  step:  28
# Episode: 156  step:  24
# Episode: 157  step:  19
# Episode: 158  step:  40
# Episode: 159  step:  21
# Episode: 160  step:  23
# Episode: 161  step:  16
# Loss:  3.00636
# Episode: 162  step:  28
# Episode: 163  step:  53
# Episode: 164  step:  35
# Episode: 165  step:  33
# Episode: 166  step:  25
# Episode: 167  step:  75
# Episode: 168  step:  40
# Episode: 169  step:  42
# Episode: 170  step:  23
# Episode: 171  step:  39
# Loss:  7.60392
# Episode: 172  step:  31
# Episode: 173  step:  40
# Episode: 174  step:  31
# Episode: 175  step:  43
# Episode: 176  step:  35
# Episode: 177  step:  22
# Episode: 178  step:  28
# Episode: 179  step:  39
# Episode: 180  step:  36
# Episode: 181  step:  29
# Loss:  3.85122
# Episode: 182  step:  9
# Episode: 183  step:  10
# Episode: 184  step:  8
# Episode: 185  step:  9
# Episode: 186  step:  9
# Episode: 187  step:  9
# Episode: 188  step:  10
# Episode: 189  step:  9
# Episode: 190  step:  11
# Episode: 191  step:  8
# Loss:  1.83787
# Episode: 192  step:  25
# Episode: 193  step:  21
# Episode: 194  step:  25
# Episode: 195  step:  29
# Episode: 196  step:  37
# Episode: 197  step:  23
# Episode: 198  step:  26
# Episode: 199  step:  44
# Episode: 200  step:  16
# Episode: 201  step:  17
# Loss:  2.0746
# Episode: 202  step:  20
# Episode: 203  step:  23
# Episode: 204  step:  23
# Episode: 205  step:  41
# Episode: 206  step:  23
# Episode: 207  step:  21
# Episode: 208  step:  27
# Episode: 209  step:  21
# Episode: 210  step:  24
# Episode: 211  step:  23
# Loss:  10.1779
# Episode: 212  step:  18
# Episode: 213  step:  20
# Episode: 214  step:  31
# Episode: 215  step:  18
# Episode: 216  step:  24
# Episode: 217  step:  29
# Episode: 218  step:  29
# Episode: 219  step:  30
# Episode: 220  step:  27
# Episode: 221  step:  31
# Loss:  19.3039
# Episode: 222  step:  28
# Episode: 223  step:  32
# Episode: 224  step:  38
# Episode: 225  step:  40
# Episode: 226  step:  23
# Episode: 227  step:  27
# Episode: 228  step:  21
# Episode: 229  step:  34
# Episode: 230  step:  22
# Episode: 231  step:  23
# Loss:  8.113
# Episode: 232  step:  26
# Episode: 233  step:  30
# Episode: 234  step:  22
# Episode: 235  step:  24
# Episode: 236  step:  23
# Episode: 237  step:  27
# Episode: 238  step:  29
# Episode: 239  step:  28
# Episode: 240  step:  22
# Episode: 241  step:  22
# Loss:  1.48639
# Episode: 242  step:  69
# Episode: 243  step:  205
# Episode: 244  step:  218
# Episode: 245  step:  58
# Episode: 246  step:  67
# Episode: 247  step:  89
# Episode: 248  step:  65
# Episode: 249  step:  101
# Episode: 250  step:  105
# Episode: 251  step:  91
# Loss:  545.598
# Episode: 252  step:  102
# Episode: 253  step:  116
# Episode: 254  step:  210
# Episode: 255  step:  147
# Episode: 256  step:  176
# Episode: 257  step:  186
# Episode: 258  step:  143
# Episode: 259  step:  200
# Episode: 260  step:  117
# Episode: 261  step:  131
# Loss:  5.11567
# Episode: 262  step:  179
# Episode: 263  step:  124
# Episode: 264  step:  167
# Episode: 265  step:  152
# Episode: 266  step:  56
# Episode: 267  step:  301
# Episode: 268  step:  76
# Episode: 269  step:  146
# Episode: 270  step:  312
# Episode: 271  step:  518
# Loss:  2.70282
# Episode: 272  step:  465
# Episode: 273  step:  249
# Episode: 274  step:  75
# Episode: 275  step:  110
# Episode: 276  step:  67
# Episode: 277  step:  114
# Episode: 278  step:  229
# Episode: 279  step:  172
# Episode: 280  step:  277
# Episode: 281  step:  147
# Loss:  1.70242
# Episode: 282  step:  431
# Episode: 283  step:  204
# Episode: 284  step:  117
# Episode: 285  step:  79
# Episode: 286  step:  110
# Episode: 287  step:  74
# Episode: 288  step:  73
# Episode: 289  step:  329
# Episode: 290  step:  60
# Episode: 291  step:  298
# Loss:  3.07522
# Episode: 292  step:  438
# Episode: 293  step:  798
# Episode: 294  step:  195
# Episode: 295  step:  910
# Episode: 296  step:  196
# Episode: 297  step:  223
# Episode: 298  step:  612
# Episode: 299  step:  519
# Episode: 300  step:  222
# Episode: 301  step:  703
# Loss:  5.84955
# Episode: 302  step:  92
# Episode: 303  step:  111
# Episode: 304  step:  91
# Episode: 305  step:  1001
# Episode: 306  step:  83
# Episode: 307  step:  608
# Episode: 308  step:  470
# Episode: 309  step:  125
# Episode: 310  step:  673
# Episode: 311  step:  108
# Loss:  5.15805
# Episode: 312  step:  1001
# Episode: 313  step:  76
# Episode: 314  step:  92
# Episode: 315  step:  113
# Episode: 316  step:  857
# Episode: 317  step:  204
# Episode: 318  step:  118
# Episode: 319  step:  86
# Episode: 320  step:  87
# Episode: 321  step:  81
# Loss:  1.77145
# Episode: 322  step:  8
# Episode: 323  step:  19
# Episode: 324  step:  9
# Episode: 325  step:  9
# Episode: 326  step:  15
# Episode: 327  step:  9
# Episode: 328  step:  13
# Episode: 329  step:  9
# Episode: 330  step:  14
# Episode: 331  step:  12
# Loss:  2.15478
# Episode: 332  step:  210
# Episode: 333  step:  129
# Episode: 334  step:  354
# Episode: 335  step:  306
# Episode: 336  step:  169
# Episode: 337  step:  786
# Episode: 338  step:  347
# Episode: 339  step:  507
# Episode: 340  step:  720
# Episode: 341  step:  332
# Loss:  5.69137
# Episode: 342  step:  68
# Episode: 343  step:  39
# Episode: 344  step:  73
# Episode: 345  step:  62
# Episode: 346  step:  61
# Episode: 347  step:  51
# Episode: 348  step:  37
# Episode: 349  step:  78
# Episode: 350  step:  75
# Episode: 351  step:  62
# Loss:  8.46276
# Episode: 352  step:  9
# Episode: 353  step:  10
# Episode: 354  step:  11
# Episode: 355  step:  10
# Episode: 356  step:  8
# Episode: 357  step:  9
# Episode: 358  step:  8
# Episode: 359  step:  9
# Episode: 360  step:  8
# Episode: 361  step:  14
# Loss:  511.877
# Episode: 362  step:  53
# Episode: 363  step:  122
# Episode: 364  step:  143
# Episode: 365  step:  81
# Episode: 366  step:  102
# Episode: 367  step:  89
# Episode: 368  step:  71
# Episode: 369  step:  94
# Episode: 370  step:  139
# Episode: 371  step:  62
# Loss:  3.44748
# Episode: 372  step:  421
# Episode: 373  step:  176
# Episode: 374  step:  251
# Episode: 375  step:  97
# Episode: 376  step:  495
# Episode: 377  step:  757
# Episode: 378  step:  77
# Episode: 379  step:  1001
# Episode: 380  step:  177
# Episode: 381  step:  407
# Loss:  4.40365
# Episode: 382  step:  71
# Episode: 383  step:  44
# Episode: 384  step:  81
# Episode: 385  step:  55
# Episode: 386  step:  51
# Episode: 387  step:  91
# Episode: 388  step:  55
# Episode: 389  step:  43
# Episode: 390  step:  55
# Episode: 391  step:  55
# Loss:  4.63228
# Episode: 392  step:  913
# Episode: 393  step:  493
# Episode: 394  step:  461
# Episode: 395  step:  446
# Episode: 396  step:  570
# Episode: 397  step:  1001
# Episode: 398  step:  536
# Episode: 399  step:  266
# Episode: 400  step:  337
# Episode: 401  step:  463
# Loss:  3.09498
# Episode: 402  step:  57
# Episode: 403  step:  109
# Episode: 404  step:  55
# Episode: 405  step:  57
# Episode: 406  step:  40
# Episode: 407  step:  61
# Episode: 408  step:  44
# Episode: 409  step:  82
# Episode: 410  step:  103
# Episode: 411  step:  71
# Loss:  1.72025
# Episode: 412  step:  22
# Episode: 413  step:  25
# Episode: 414  step:  30
# Episode: 415  step:  21
# Episode: 416  step:  37
# Episode: 417  step:  26
# Episode: 418  step:  22
# Episode: 419  step:  51
# Episode: 420  step:  23
# Episode: 421  step:  36
# Loss:  3.10449
# Episode: 422  step:  536
# Episode: 423  step:  649
# Episode: 424  step:  461
# Episode: 425  step:  326
# Episode: 426  step:  157
# Episode: 427  step:  154
# Episode: 428  step:  516
# Episode: 429  step:  459
# Episode: 430  step:  226
# Episode: 431  step:  208
# Loss:  0.849428
# Episode: 432  step:  24
# Episode: 433  step:  26
# Episode: 434  step:  22
# Episode: 435  step:  22
# Episode: 436  step:  26
# Episode: 437  step:  23
# Episode: 438  step:  50
# Episode: 439  step:  26
# Episode: 440  step:  41
# Episode: 441  step:  44
# Loss:  3.09321
# Episode: 442  step:  47
# Episode: 443  step:  27
# Episode: 444  step:  22
# Episode: 445  step:  46
# Episode: 446  step:  30
# Episode: 447  step:  46
# Episode: 448  step:  49
# Episode: 449  step:  31
# Episode: 450  step:  36
# Episode: 451  step:  31
# Loss:  4.31652
# Episode: 452  step:  10
# Episode: 453  step:  11
# Episode: 454  step:  11
# Episode: 455  step:  9
# Episode: 456  step:  10
# Episode: 457  step:  17
# Episode: 458  step:  13
# Episode: 459  step:  11
# Episode: 460  step:  10
# Episode: 461  step:  10
# Loss:  2.3383
# Episode: 462  step:  23
# Episode: 463  step:  35
# Episode: 464  step:  32
# Episode: 465  step:  32
# Episode: 466  step:  25
# Episode: 467  step:  24
# Episode: 468  step:  23
# Episode: 469  step:  20
# Episode: 470  step:  22
# Episode: 471  step:  23
# Loss:  467.784
# Episode: 472  step:  161
# Episode: 473  step:  137
# Episode: 474  step:  137
# Episode: 475  step:  182
# Episode: 476  step:  136
# Episode: 477  step:  367
# Episode: 478  step:  259
# Episode: 479  step:  103
# Episode: 480  step:  101
# Episode: 481  step:  149
# Loss:  2.91219
# Episode: 482  step:  118
# Episode: 483  step:  281
# Episode: 484  step:  595
# Episode: 485  step:  117
# Episode: 486  step:  291
# Episode: 487  step:  1001
# Episode: 488  step:  189
# Episode: 489  step:  127
# Episode: 490  step:  130
# Episode: 491  step:  177
# Loss:  1.36235
# Episode: 492  step:  78
# Episode: 493  step:  67
# Episode: 494  step:  93
# Episode: 495  step:  67
# Episode: 496  step:  49
# Episode: 497  step:  55
# Episode: 498  step:  59
# Episode: 499  step:  39
# Episode: 500  step:  51
# Episode: 501  step:  56
# Loss:  0.996832
# Episode: 502  step:  82
# Episode: 503  step:  75
# Episode: 504  step:  67
# Episode: 505  step:  46
# Episode: 506  step:  88
# Episode: 507  step:  75
# Episode: 508  step:  38
# Episode: 509  step:  54
# Episode: 510  step:  82
# Episode: 511  step:  59
# Loss:  2.90388
# Episode: 512  step:  35
# Episode: 513  step:  33
# Episode: 514  step:  33
# Episode: 515  step:  33
# Episode: 516  step:  27
# Episode: 517  step:  48
# Episode: 518  step:  37
# Episode: 519  step:  32
# Episode: 520  step:  36
# Episode: 521  step:  43
# Loss:  5.77789
# Episode: 522  step:  74
# Episode: 523  step:  72
# Episode: 524  step:  58
# Episode: 525  step:  87
# Episode: 526  step:  102
# Episode: 527  step:  79
# Episode: 528  step:  84
# Episode: 529  step:  58
# Episode: 530  step:  60
# Episode: 531  step:  49
# Loss:  4.58495
# Episode: 532  step:  1001
# Episode: 533  step:  435
# Episode: 534  step:  99
# Episode: 535  step:  99
# Episode: 536  step:  669
# Episode: 537  step:  1001
# Episode: 538  step:  83
# Episode: 539  step:  649
# Episode: 540  step:  714
# Episode: 541  step:  101
# Loss:  2.54459
# Episode: 542  step:  352
# Episode: 543  step:  73
# Episode: 544  step:  153
# Episode: 545  step:  452
# Episode: 546  step:  1001
# Episode: 547  step:  85
# Episode: 548  step:  114
# Episode: 549  step:  208
# Episode: 550  step:  107
# Episode: 551  step:  84
# Loss:  10.4187
# Episode: 552  step:  12
# Episode: 553  step:  9
# Episode: 554  step:  10
# Episode: 555  step:  9
# Episode: 556  step:  10
# Episode: 557  step:  8
# Episode: 558  step:  9
# Episode: 559  step:  10
# Episode: 560  step:  8
# Episode: 561  step:  11
# Loss:  4.59941
# Episode: 562  step:  33
# Episode: 563  step:  59
# Episode: 564  step:  34
# Episode: 565  step:  36
# Episode: 566  step:  29
# Episode: 567  step:  53
# Episode: 568  step:  36
# Episode: 569  step:  29
# Episode: 570  step:  38
# Episode: 571  step:  65
# Loss:  3.19607
# Episode: 572  step:  25
# Episode: 573  step:  25
# Episode: 574  step:  44
# Episode: 575  step:  46
# Episode: 576  step:  65
# Episode: 577  step:  25
# Episode: 578  step:  43
# Episode: 579  step:  65
# Episode: 580  step:  126
# Episode: 581  step:  26
# Loss:  1.29599
# Episode: 582  step:  28
# Episode: 583  step:  60
# Episode: 584  step:  24
# Episode: 585  step:  87
# Episode: 586  step:  21
# Episode: 587  step:  92
# Episode: 588  step:  67
# Episode: 589  step:  89
# Episode: 590  step:  21
# Episode: 591  step:  22
# Loss:  2.11457
# Episode: 592  step:  24
# Episode: 593  step:  68
# Episode: 594  step:  93
# Episode: 595  step:  60
# Episode: 596  step:  80
# Episode: 597  step:  41
# Episode: 598  step:  54
# Episode: 599  step:  22
# Episode: 600  step:  22
# Episode: 601  step:  18
# Loss:  0.70167
# Episode: 602  step:  1001
# Episode: 603  step:  1001
# Episode: 604  step:  1001
# Episode: 605  step:  1001
# Episode: 606  step:  1001
# Episode: 607  step:  1001
# Episode: 608  step:  1001
# Episode: 609  step:  1001
# Episode: 610  step:  1001
# Episode: 611  step:  1001
# Loss:  0.966682
# Episode: 612  step:  27
# Episode: 613  step:  104
# Episode: 614  step:  61
# Episode: 615  step:  127
# Episode: 616  step:  22
# Episode: 617  step:  41
# Episode: 618  step:  52
# Episode: 619  step:  24
# Episode: 620  step:  302
# Episode: 621  step:  144
# Loss:  0.661876
# Episode: 622  step:  34
# Episode: 623  step:  83
# Episode: 624  step:  47
# Episode: 625  step:  85
# Episode: 626  step:  39
# Episode: 627  step:  240
# Episode: 628  step:  30
# Episode: 629  step:  39
# Episode: 630  step:  101
# Episode: 631  step:  197
# Loss:  2.21481
# Episode: 632  step:  1001
# Episode: 633  step:  1001
# Episode: 634  step:  1001
# Episode: 635  step:  1001
# Episode: 636  step:  1001
# Episode: 637  step:  1001
# Episode: 638  step:  1001
# Episode: 639  step:  1001
# Episode: 640  step:  1001
# Episode: 641  step:  1001
# Loss:  1.19797
# Episode: 642  step:  46
# Episode: 643  step:  58
# Episode: 644  step:  48
# Episode: 645  step:  52
# Episode: 646  step:  60
# Episode: 647  step:  46
# Episode: 648  step:  100
# Episode: 649  step:  61
# Episode: 650  step:  59
# Episode: 651  step:  61
# Loss:  3.72388
# Episode: 652  step:  1001
# Episode: 653  step:  1001
# Episode: 654  step:  1001
# Episode: 655  step:  1001
# Episode: 656  step:  1001
# Episode: 657  step:  1001
# Episode: 658  step:  1001
# Episode: 659  step:  1001
# Episode: 660  step:  1001
# Episode: 661  step:  1001
# Loss:  1.21751
# Episode: 662  step:  1001
# Episode: 663  step:  1001
# Episode: 664  step:  1001
# Episode: 665  step:  1001
# Episode: 666  step:  1001
# Episode: 667  step:  1001
# Episode: 668  step:  1001
# Episode: 669  step:  1001
# Episode: 670  step:  1001
# Episode: 671  step:  1001
# Loss:  0.692955
# Episode: 672  step:  1001
# Episode: 673  step:  1001
# Episode: 674  step:  1001
# Episode: 675  step:  1001
# Episode: 676  step:  1001
# Episode: 677  step:  1001
# Episode: 678  step:  1001
# Episode: 679  step:  1001
# Episode: 680  step:  1001
# Episode: 681  step:  1001
# Loss:  2.45398
# Episode: 682  step:  1001
# Episode: 683  step:  1001
# Episode: 684  step:  1001
# Episode: 685  step:  1001
# Episode: 686  step:  1001
# Episode: 687  step:  1001
# Episode: 688  step:  1001
# Episode: 689  step:  1001
# Episode: 690  step:  1001
# Episode: 691  step:  1001
# Loss:  0.643834
# Episode: 692  step:  1001
# Episode: 693  step:  1001
# Episode: 694  step:  1001
# Episode: 695  step:  1001
# Episode: 696  step:  1001
# Episode: 697  step:  1001
# Episode: 698  step:  326
# Episode: 699  step:  1001
# Episode: 700  step:  1001
# Episode: 701  step:  1001
# Loss:  0.977821
# Episode: 702  step:  1001
# Episode: 703  step:  1001
# Episode: 704  step:  1001
# Episode: 705  step:  1001
# Episode: 706  step:  1001
# Episode: 707  step:  1001
# Episode: 708  step:  1001
# Episode: 709  step:  1001
# Episode: 710  step:  1001
# Episode: 711  step:  1001
# Loss:  1.96583
# Episode: 712  step:  1001
# Episode: 713  step:  1001
# Episode: 714  step:  1001
# Episode: 715  step:  1001
# Episode: 716  step:  1001
# Episode: 717  step:  1001
# Episode: 718  step:  1001
# Episode: 719  step:  813
# Episode: 720  step:  1001
# Episode: 721  step:  1001
# Loss:  1.54834
# Episode: 722  step:  1001
# Episode: 723  step:  1001
# Episode: 724  step:  1001
# Episode: 725  step:  1001
# Episode: 726  step:  1001
# Episode: 727  step:  501
# Episode: 728  step:  431
# Episode: 729  step:  1001
# Episode: 730  step:  506
# Episode: 731  step:  456
# Loss:  2.87883
# Episode: 732  step:  1001
# Episode: 733  step:  1001
# Episode: 734  step:  524
# Episode: 735  step:  774
# Episode: 736  step:  1001
# Episode: 737  step:  1001
# Episode: 738  step:  1001
# Episode: 739  step:  584
# Episode: 740  step:  1001
# Episode: 741  step:  1001
# Loss:  2.16869
# Episode: 742  step:  1001
# Episode: 743  step:  1001
# Episode: 744  step:  732
# Episode: 745  step:  1001
# Episode: 746  step:  1001
# Episode: 747  step:  552
# Episode: 748  step:  1001
# Episode: 749  step:  780
# Episode: 750  step:  1001
# Episode: 751  step:  1001
# Loss:  2.30649
# Episode: 752  step:  1001
# Episode: 753  step:  1001
# Episode: 754  step:  1001
# Episode: 755  step:  1001
# Episode: 756  step:  1001
# Episode: 757  step:  1001
# Episode: 758  step:  1001
# Episode: 759  step:  1001
# Episode: 760  step:  1001
# Episode: 761  step:  1001
# Loss:  0.357284
# Episode: 762  step:  716
# Episode: 763  step:  1001
# Episode: 764  step:  747
# Episode: 765  step:  1001
# Episode: 766  step:  716
# Episode: 767  step:  230
# Episode: 768  step:  298
# Episode: 769  step:  354
# Episode: 770  step:  1001
# Episode: 771  step:  1001
# Loss:  1.19769
# Episode: 772  step:  1001
# Episode: 773  step:  350
# Episode: 774  step:  391
# Episode: 775  step:  1001
# Episode: 776  step:  1001
# Episode: 777  step:  1001
# Episode: 778  step:  925
# Episode: 779  step:  1001
# Episode: 780  step:  358
# Episode: 781  step:  386
# Loss:  0.415458
# Episode: 782  step:  1001
# Episode: 783  step:  1001
# Episode: 784  step:  1001
# Episode: 785  step:  354
# Episode: 786  step:  1001
# Episode: 787  step:  1001
# Episode: 788  step:  337
# Episode: 789  step:  1001
# Episode: 790  step:  1001
# Episode: 791  step:  377
# Loss:  2.3272
# Episode: 792  step:  1001
# Episode: 793  step:  1001
# Episode: 794  step:  1001
# Episode: 795  step:  1001
# Episode: 796  step:  1001
# Episode: 797  step:  1001
# Episode: 798  step:  1001
# Episode: 799  step:  1001
# Episode: 800  step:  1001
# Episode: 801  step:  1001
# Loss:  0.944191
# Episode: 802  step:  1001
# Episode: 803  step:  1001
# Episode: 804  step:  1001
# Episode: 805  step:  1001
# Episode: 806  step:  1001
# Episode: 807  step:  1001
# Episode: 808  step:  1001
# Episode: 809  step:  647
# Episode: 810  step:  1001
# Episode: 811  step:  1001
# Loss:  4.13547
# Episode: 812  step:  1001
# Episode: 813  step:  1001
# Episode: 814  step:  1001
# Episode: 815  step:  1001
# Episode: 816  step:  1001
# Episode: 817  step:  1001
# Episode: 818  step:  1001
# Episode: 819  step:  1001
# Episode: 820  step:  1001
# Episode: 821  step:  1001
# Loss:  1.26529
# Episode: 822  step:  1001
# Episode: 823  step:  1001
# Episode: 824  step:  1001
# Episode: 825  step:  1001
# Episode: 826  step:  1001
# Episode: 827  step:  1001
# Episode: 828  step:  1001
# Episode: 829  step:  1001
# Episode: 830  step:  1001
# Episode: 831  step:  1001
# Loss:  1.90449
# Episode: 832  step:  1001
# Episode: 833  step:  614
# Episode: 834  step:  803
# Episode: 835  step:  1001
# Episode: 836  step:  1001
# Episode: 837  step:  1001
# Episode: 838  step:  1001
# Episode: 839  step:  1001
# Episode: 840  step:  1001
# Episode: 841  step:  1001
# Loss:  1.66991
# Episode: 842  step:  1001
# Episode: 843  step:  1001
# Episode: 844  step:  1001
# Episode: 845  step:  986
# Episode: 846  step:  1001
# Episode: 847  step:  612
# Episode: 848  step:  1001
# Episode: 849  step:  1001
# Episode: 850  step:  817
# Episode: 851  step:  1001
# Loss:  3.59796
# Episode: 852  step:  793
# Episode: 853  step:  1001
# Episode: 854  step:  1001
# Episode: 855  step:  1001
# Episode: 856  step:  472
# Episode: 857  step:  176
# Episode: 858  step:  284
# Episode: 859  step:  1001
# Episode: 860  step:  210
# Episode: 861  step:  248
# Loss:  3.96733
# Episode: 862  step:  300
# Episode: 863  step:  1001
# Episode: 864  step:  1001
# Episode: 865  step:  513
# Episode: 866  step:  1001
# Episode: 867  step:  1001
# Episode: 868  step:  1001
# Episode: 869  step:  1001
# Episode: 870  step:  1001
# Episode: 871  step:  284
# Loss:  1.00816
# Episode: 872  step:  355
# Episode: 873  step:  1001
# Episode: 874  step:  1001
# Episode: 875  step:  1001
# Episode: 876  step:  1001
# Episode: 877  step:  349
# Episode: 878  step:  1001
# Episode: 879  step:  1001
# Episode: 880  step:  1001
# Episode: 881  step:  1001
# Loss:  2.74475
# Episode: 882  step:  994
# Episode: 883  step:  1001
# Episode: 884  step:  1001
# Episode: 885  step:  553
# Episode: 886  step:  1001
# Episode: 887  step:  1001
# Episode: 888  step:  838
# Episode: 889  step:  565
# Episode: 890  step:  698
# Episode: 891  step:  1001
# Loss:  5.40169
# Episode: 892  step:  1001
# Episode: 893  step:  514
# Episode: 894  step:  1001
# Episode: 895  step:  1001
# Episode: 896  step:  1001
# Episode: 897  step:  1001
# Episode: 898  step:  1001
# Episode: 899  step:  937
# Episode: 900  step:  1001
# Episode: 901  step:  1001
# Loss:  2.32994
# Episode: 902  step:  1001
# Episode: 903  step:  1001
# Episode: 904  step:  1001
# Episode: 905  step:  1001
# Episode: 906  step:  1001
# Episode: 907  step:  1001
# Episode: 908  step:  530
# Episode: 909  step:  488
# Episode: 910  step:  922
# Episode: 911  step:  1001
# Loss:  1.19525
# Episode: 912  step:  1001
# Episode: 913  step:  1001
# Episode: 914  step:  1001
# Episode: 915  step:  1001
# Episode: 916  step:  1001
# Episode: 917  step:  1001
# Episode: 918  step:  1001
# Episode: 919  step:  872
# Episode: 920  step:  855
# Episode: 921  step:  187
# Loss:  2.27476
# Episode: 922  step:  1001
# Episode: 923  step:  1001
# Episode: 924  step:  608
# Episode: 925  step:  1001
# Episode: 926  step:  1001
# Episode: 927  step:  1001
# Episode: 928  step:  662
# Episode: 929  step:  1001
# Episode: 930  step:  1001
# Episode: 931  step:  563
# Loss:  1.1653
# Episode: 932  step:  605
# Episode: 933  step:  1001
# Episode: 934  step:  1001
# Episode: 935  step:  1001
# Episode: 936  step:  1001
# Episode: 937  step:  1001
# Episode: 938  step:  1001
# Episode: 939  step:  1001
# Episode: 940  step:  1001
# Episode: 941  step:  1001
# Loss:  2.7485
# Episode: 942  step:  1001
# Episode: 943  step:  1001
# Episode: 944  step:  1001
# Episode: 945  step:  1001
# Episode: 946  step:  1001
# Episode: 947  step:  1001
# Episode: 948  step:  1001
# Episode: 949  step:  1001
# Episode: 950  step:  1001
# Episode: 951  step:  1001
# Loss:  3.99799
# Episode: 952  step:  263
# Episode: 953  step:  1001
# Episode: 954  step:  1001
# Episode: 955  step:  1001
# Episode: 956  step:  1001
# Episode: 957  step:  1001
# Episode: 958  step:  404
# Episode: 959  step:  1001
# Episode: 960  step:  1001
# Episode: 961  step:  401
# Loss:  3.49527
# Episode: 962  step:  396
# Episode: 963  step:  1001
# Episode: 964  step:  1001
# Episode: 965  step:  1001
# Episode: 966  step:  639
# Episode: 967  step:  1001
# Episode: 968  step:  480
# Episode: 969  step:  1001
# Episode: 970  step:  1001
# Episode: 971  step:  1001
# Loss:  1.68945
# Episode: 972  step:  1001
# Episode: 973  step:  1001
# Episode: 974  step:  1001
# Episode: 975  step:  1001
# Episode: 976  step:  564
# Episode: 977  step:  770
# Episode: 978  step:  1001
# Episode: 979  step:  1001
# Episode: 980  step:  767
# Episode: 981  step:  1001
# Loss:  1.56462
# Episode: 982  step:  1001
# Episode: 983  step:  1001
# Episode: 984  step:  1001
# Episode: 985  step:  829
# Episode: 986  step:  1001
# Episode: 987  step:  1001
# Episode: 988  step:  1001
# Episode: 989  step:  1001
# Episode: 990  step:  1001
# Episode: 991  step:  1001
# Loss:  1.11311
# Episode: 992  step:  1001
# Episode: 993  step:  1001
# Episode: 994  step:  1001
# Episode: 995  step:  583
# Episode: 996  step:  288
# Episode: 997  step:  1001
# Episode: 998  step:  1001
# Episode: 999  step:  1001
# Total score: 276.0
