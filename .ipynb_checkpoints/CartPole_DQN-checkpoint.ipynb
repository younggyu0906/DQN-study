# %%
import numpy as np
import tensorflow as tf
import random
import dqn
from collections import deque

import gym
env = gym.make('CartPole-v0')

# Constants defining our neural network
input_size = env.observation_space.shape[0]
output_size = env.action_space.n

mainDQN = None

dis = 0.9
REPLAY_MEMORY = 50000
# Out:
# [2017-11-14 14:09:35,457] Making new env: CartPole-v0

# %%
class DQN:
    def __init__(self, session, input_size, output_size, name="main"):
        self.session = session
        self.input_size = input_size
        self.output_size = output_size
        self.net_name = name
        
        self._build_network()
        
    def _build_network(self, h_size = 10, l_rate = 1e-1):
        with tf.variable_scope(self.net_name):
            self._X = tf.placeholder(
                tf.float32, [None, self.input_size], name = "input_x")
        
            # First layer of weights
            W1 = tf.get_variable("W1", shape=[self.input_size, h_size],
                             initializer=tf.contrib.layers.xavier_initializer())
            layer1 = tf.nn.tanh(tf.matmul(self._X, W1))
        
            # Second Layer of weights
            W2 = tf.get_variable("W2", shape=[h_size, self.output_size],
                             initializer=tf.contrib.layers.xavier_initializer())
        
            # Q prediction
            self._Qpred = tf.matmul(layer1, W2)
        
        # We need to define the parts of the network needed for learning a policy
        self._Y = tf.placeholder(
            shape = [None, self.output_size], dtype = tf.float32)
    
        # Loss function
        self._loss = tf.reduce_mean(tf.square(self._Y - self._Qpred))
        # Learning
        self._train = tf.train.AdamOptimizer(
            learning_rate=l_rate).minimize(self._loss)
    
    def predict(self, state):
        x = np.reshape(state, [1, self.input_size])
        return self.session.run(self._Qpred, feed_dict = {self._X: x})
    
    def update(self, x_stack, y_stack):
        return self.session.run([self._loss, self._train], feed_dict = 
                               {self._X: x_stack, self._Y: y_stack})

# %%
def replay_train(mainDQN, targetDQN, train_batch):
    x_stack = np.empty(0).reshape(0, input_size)
    y_stack = np.empty(0).reshape(0, output_size)
    
    # Get stored information from the buffer
    for state, action, reward, next_state, done in train_batch:
        Q = mainDQN.predict(state)
        
        # terminal?
        if done:
            Q[0, action] = reward
        else:
            # get target from target DQN (Q')
            Q[0, action] = reward + dis * np.max(targetDQN.predict(next_state))
            
        y_stack = np.vstack([y_stack, Q])
        x_stack = np.vstack([x_stack, state])
        
    # Train our network using target and predicted Q values on each episode
    return mainDQN.update(x_stack, y_stack)

# %%
def get_copy_var_ops(*, dest_scope_name = "target", src_scope_name = "main"):
    # Copy variables src_scope to dest_scope
    op_holder = []
    
    src_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope = src_scope_name)
    dest_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope = dest_scope_name)
    
    for src_var, dest_var in zip(src_vars, dest_vars):
        op_holder.append(dest_var.assign(src_var.value()))
        
    return op_holder

# %%
def bot_play(mainDQN):
    # See our trained network in action
    s = env.reset()
    reward_sum = 0
    while True:
        env.render()
        a = np.argmax(mainDQN.predict(s))
        s, reward, done, _ = env.step(a)
        reward_sum += reward
        if done:
            print("Total score: {}".format(reward_sum))
            break

# %%
def main():
    max_episodes = 5000
    # store the previous observations in replay memory
    replay_buffer = deque()
    
    with tf.Session() as sess:
        mainDQN = DQN(sess, input_size, output_size, name = "main")
        targetDQN = DQN(sess, input_size, output_size, name = "target")
        tf.global_variables_initializer().run()
    
        # initial copy q_net -> target_net
        copy_ops = get_copy_var_ops(dest_scope_name = "target", src_scope_name = "main")
    
        sess.run(copy_ops)
    
        for episode in range(max_episodes):
            e = 1. / ((episode / 10) + 1)
            done = False
            step_count = 0
            state = env.reset()
        
            while not done:
                if np.random.rand(1) < e:
                    action = env.action_space.sample()
                else:
                    # Choose an action by greedily from the Q-netsork
                    action = np.argmax(mainDQN.predict(state))
                
                # Get new state and reward from environment
                next_state, reward, done, _ = env.step(action)
                if done: # Penalty
                    reward = -100
                
                # Save the experience to our buffer
                replay_buffer.append((state, action, reward, next_state, done))
                if len(replay_buffer) > REPLAY_MEMORY:
                    replay_buffer.popleft()

                state = next_state
                step_count += 1
                if step_count > 10000: # Good enough. Let's move on
                    break

            print("Episode: {}  step:  {}".format(episode, step_count))
            if step_count > 10000:
                pass
                # break

            if episode % 10 == 1:  # train every 10 episode
                # Get a random batch of experiences.
                for _ in range(50):
                    minibatch = random.sample(replay_buffer, 10)
                    loss, _ = replay_train(mainDQN, targetDQN, minibatch)

                print("Loss: ", loss)
                #copy q_net -> target_net
                sess.run(copy_ops)

        bot_play(mainDQN)
            
if __name__ == "__main__":
    main()
# Out:
# Episode: 0  step:  14
# Episode: 1  step:  10
# Loss:  0.727751
# Episode: 2  step:  58
# Episode: 3  step:  29
# Episode: 4  step:  31
# Episode: 5  step:  18
# Episode: 6  step:  35
# Episode: 7  step:  24
# Episode: 8  step:  28
# Episode: 9  step:  15
# Episode: 10  step:  32
# Episode: 11  step:  23
# Loss:  2.52683
# Episode: 12  step:  58
# Episode: 13  step:  122
# Episode: 14  step:  29
# Episode: 15  step:  139
# Episode: 16  step:  69
# Episode: 17  step:  74
# Episode: 18  step:  101
# Episode: 19  step:  56
# Episode: 20  step:  56
# Episode: 21  step:  102
# Loss:  2.00315
# Episode: 22  step:  11
# Episode: 23  step:  10
# Episode: 24  step:  10
# Episode: 25  step:  11
# Episode: 26  step:  10
# Episode: 27  step:  11
# Episode: 28  step:  10
# Episode: 29  step:  10
# Episode: 30  step:  9
# Episode: 31  step:  9
# Loss:  474.02
# Episode: 32  step:  40
# Episode: 33  step:  19
# Episode: 34  step:  30
# Episode: 35  step:  42
# Episode: 36  step:  29
# Episode: 37  step:  19
# Episode: 38  step:  56
# Episode: 39  step:  50
# Episode: 40  step:  28
# Episode: 41  step:  62
# Loss:  4.05838
# Episode: 42  step:  47
# Episode: 43  step:  86
# Episode: 44  step:  96
# Episode: 45  step:  70
# Episode: 46  step:  40
# Episode: 47  step:  66
# Episode: 48  step:  77
# Episode: 49  step:  63
# Episode: 50  step:  92
# Episode: 51  step:  54
# Loss:  0.734798
# Episode: 52  step:  55
# Episode: 53  step:  86
# Episode: 54  step:  196
# Episode: 55  step:  88
# Episode: 56  step:  140
# Episode: 57  step:  137
# Episode: 58  step:  50
# Episode: 59  step:  112
# Episode: 60  step:  71
# Episode: 61  step:  85
# Loss:  2.35872
# Episode: 62  step:  11
# Episode: 63  step:  10
# Episode: 64  step:  11
# Episode: 65  step:  10
# Episode: 66  step:  12
# Episode: 67  step:  12
# Episode: 68  step:  11
# Episode: 69  step:  10
# Episode: 70  step:  8
# Episode: 71  step:  10
# Loss:  3.58492
# Episode: 72  step:  32
# Episode: 73  step:  80
# Episode: 74  step:  23
# Episode: 75  step:  37
# Episode: 76  step:  21
# Episode: 77  step:  36
# Episode: 78  step:  39
# Episode: 79  step:  33
# Episode: 80  step:  26
# Episode: 81  step:  34
# Loss:  11.1449
# Episode: 82  step:  61
# Episode: 83  step:  118
# Episode: 84  step:  135
# Episode: 85  step:  200
# Episode: 86  step:  59
# Episode: 87  step:  74
# Episode: 88  step:  66
# Episode: 89  step:  88
# Episode: 90  step:  42
# Episode: 91  step:  44
# Loss:  7.72165
# Episode: 92  step:  9
# Episode: 93  step:  10
# Episode: 94  step:  10
# Episode: 95  step:  9
# Episode: 96  step:  10
# Episode: 97  step:  9
# Episode: 98  step:  11
# Episode: 99  step:  9
# Episode: 100  step:  10
# Episode: 101  step:  9
# Loss:  4.79978
# Episode: 102  step:  10
# Episode: 103  step:  10
# Episode: 104  step:  9
# Episode: 105  step:  9
# Episode: 106  step:  8
# Episode: 107  step:  9
# Episode: 108  step:  11
# Episode: 109  step:  9
# Episode: 110  step:  10
# Episode: 111  step:  9
# Loss:  1.29701
# Episode: 112  step:  23
# Episode: 113  step:  24
# Episode: 114  step:  34
# Episode: 115  step:  22
# Episode: 116  step:  32
# Episode: 117  step:  46
# Episode: 118  step:  44
# Episode: 119  step:  36
# Episode: 120  step:  42
# Episode: 121  step:  51
# Loss:  2.49103
# Episode: 122  step:  31
# Episode: 123  step:  28
# Episode: 124  step:  21
# Episode: 125  step:  23
# Episode: 126  step:  21
# Episode: 127  step:  40
# Episode: 128  step:  22
# Episode: 129  step:  45
# Episode: 130  step:  19
# Episode: 131  step:  65
# Loss:  1.17538
# Episode: 132  step:  200
# Episode: 133  step:  200
# Episode: 134  step:  200
# Episode: 135  step:  200
# Episode: 136  step:  200
# Episode: 137  step:  168
# Episode: 138  step:  200
# Episode: 139  step:  200
# Episode: 140  step:  200
# Episode: 141  step:  200
# Loss:  11.4525
# Episode: 142  step:  35
# Episode: 143  step:  36
# Episode: 144  step:  15
# Episode: 145  step:  33
# Episode: 146  step:  36
# Episode: 147  step:  38
# Episode: 148  step:  36
# Episode: 149  step:  35
# Episode: 150  step:  35
# Episode: 151  step:  35
# Loss:  1.56858
# Episode: 152  step:  25
# Episode: 153  step:  20
# Episode: 154  step:  20
# Episode: 155  step:  19
# Episode: 156  step:  18
# Episode: 157  step:  32
# Episode: 158  step:  15
# Episode: 159  step:  19
# Episode: 160  step:  42
# Episode: 161  step:  14
# Loss:  2.95058
# Episode: 162  step:  20
# Episode: 163  step:  36
# Episode: 164  step:  40
# Episode: 165  step:  22
# Episode: 166  step:  33
# Episode: 167  step:  36
# Episode: 168  step:  50
# Episode: 169  step:  25
# Episode: 170  step:  36
# Episode: 171  step:  23
# Loss:  3.06236
# Episode: 172  step:  31
# Episode: 173  step:  40
# Episode: 174  step:  19
# Episode: 175  step:  30
# Episode: 176  step:  21
# Episode: 177  step:  19
# Episode: 178  step:  16
# Episode: 179  step:  17
# Episode: 180  step:  28
# Episode: 181  step:  27
# Loss:  7.95049
# Episode: 182  step:  50
# Episode: 183  step:  38
# Episode: 184  step:  44
# Episode: 185  step:  60
# Episode: 186  step:  54
# Episode: 187  step:  41
# Episode: 188  step:  31
# Episode: 189  step:  30
# Episode: 190  step:  40
# Episode: 191  step:  50
# Loss:  512.26
# Episode: 192  step:  28
# Episode: 193  step:  20
# Episode: 194  step:  23
# Episode: 195  step:  31
# Episode: 196  step:  18
# Episode: 197  step:  25
# Episode: 198  step:  34
# Episode: 199  step:  25
# Episode: 200  step:  39
# Episode: 201  step:  20
# Loss:  1484.3
# Episode: 202  step:  45
# Episode: 203  step:  33
# Episode: 204  step:  49
# Episode: 205  step:  23
# Episode: 206  step:  23
# Episode: 207  step:  32
# Episode: 208  step:  53
# Episode: 209  step:  81
# Episode: 210  step:  23
# Episode: 211  step:  31
# Loss:  3.28813
# Episode: 212  step:  32
# Episode: 213  step:  20
# Episode: 214  step:  17
# Episode: 215  step:  84
# Episode: 216  step:  20
# Episode: 217  step:  18
# Episode: 218  step:  26
# Episode: 219  step:  25
# Episode: 220  step:  23
# Episode: 221  step:  38
# Loss:  498.058
# Episode: 222  step:  24
# Episode: 223  step:  10
# Episode: 224  step:  10
# Episode: 225  step:  14
# Episode: 226  step:  10
# Episode: 227  step:  10
# Episode: 228  step:  11
# Episode: 229  step:  12
# Episode: 230  step:  10
# Episode: 231  step:  15
# Loss:  530.197
# Episode: 232  step:  49
# Episode: 233  step:  23
# Episode: 234  step:  17
# Episode: 235  step:  32
# Episode: 236  step:  20
# Episode: 237  step:  16
# Episode: 238  step:  25
# Episode: 239  step:  17
# Episode: 240  step:  27
# Episode: 241  step:  14
# Loss:  4.433
# Episode: 242  step:  54
# Episode: 243  step:  27
# Episode: 244  step:  28
# Episode: 245  step:  100
# Episode: 246  step:  51
# Episode: 247  step:  40
# Episode: 248  step:  67
# Episode: 249  step:  67
# Episode: 250  step:  23
# Episode: 251  step:  35
# Loss:  3.18089
# Episode: 252  step:  54
# Episode: 253  step:  22
# Episode: 254  step:  28
# Episode: 255  step:  31
# Episode: 256  step:  77
# Episode: 257  step:  28
# Episode: 258  step:  22
# Episode: 259  step:  44
# Episode: 260  step:  66
# Episode: 261  step:  25
# Loss:  3.74582
# Episode: 262  step:  49
# Episode: 263  step:  36
# Episode: 264  step:  56
# Episode: 265  step:  80
# Episode: 266  step:  73
# Episode: 267  step:  154
# Episode: 268  step:  56
# Episode: 269  step:  76
# Episode: 270  step:  37
# Episode: 271  step:  68
# Loss:  7.31795
# Episode: 272  step:  8
# Episode: 273  step:  9
# Episode: 274  step:  10
# Episode: 275  step:  11
# Episode: 276  step:  9
# Episode: 277  step:  8
# Episode: 278  step:  9
# Episode: 279  step:  10
# Episode: 280  step:  10
# Episode: 281  step:  10
# Loss:  5.45621
# Episode: 282  step:  76
# Episode: 283  step:  51
# Episode: 284  step:  52
# Episode: 285  step:  81
# Episode: 286  step:  66
# Episode: 287  step:  68
# Episode: 288  step:  41
# Episode: 289  step:  43
# Episode: 290  step:  70
# Episode: 291  step:  70
# Loss:  5.13551
# Episode: 292  step:  63
# Episode: 293  step:  61
# Episode: 294  step:  111
# Episode: 295  step:  84
# Episode: 296  step:  58
# Episode: 297  step:  163
# Episode: 298  step:  58
# Episode: 299  step:  55
# Episode: 300  step:  60
# Episode: 301  step:  63
# Loss:  510.988
# Episode: 302  step:  26
# Episode: 303  step:  37
# Episode: 304  step:  21
# Episode: 305  step:  25
# Episode: 306  step:  26
# Episode: 307  step:  17
# Episode: 308  step:  29
# Episode: 309  step:  28
# Episode: 310  step:  21
# Episode: 311  step:  33
# Loss:  1.03154
# Episode: 312  step:  78
# Episode: 313  step:  120
# Episode: 314  step:  115
# Episode: 315  step:  106
# Episode: 316  step:  98
# Episode: 317  step:  83
# Episode: 318  step:  86
# Episode: 319  step:  82
# Episode: 320  step:  105
# Episode: 321  step:  111
# Loss:  3.37473
# Episode: 322  step:  32
# Episode: 323  step:  30
# Episode: 324  step:  26
# Episode: 325  step:  29
# Episode: 326  step:  21
# Episode: 327  step:  25
# Episode: 328  step:  23
# Episode: 329  step:  33
# Episode: 330  step:  22
# Episode: 331  step:  23
# Loss:  2.78619
# Episode: 332  step:  71
# Episode: 333  step:  103
# Episode: 334  step:  59
# Episode: 335  step:  52
# Episode: 336  step:  68
# Episode: 337  step:  47
# Episode: 338  step:  94
# Episode: 339  step:  79
# Episode: 340  step:  77
# Episode: 341  step:  55
# Loss:  567.678
# Episode: 342  step:  47
# Episode: 343  step:  54
# Episode: 344  step:  60
# Episode: 345  step:  59
# Episode: 346  step:  61
# Episode: 347  step:  45
# Episode: 348  step:  82
# Episode: 349  step:  99
# Episode: 350  step:  56
# Episode: 351  step:  46
# Loss:  504.677
# Episode: 352  step:  37
# Episode: 353  step:  61
# Episode: 354  step:  36
# Episode: 355  step:  44
# Episode: 356  step:  48
# Episode: 357  step:  40
# Episode: 358  step:  34
# Episode: 359  step:  58
# Episode: 360  step:  56
# Episode: 361  step:  49
# Loss:  3.63016
# Episode: 362  step:  52
# Episode: 363  step:  71
# Episode: 364  step:  74
# Episode: 365  step:  53
# Episode: 366  step:  35
# Episode: 367  step:  69
# Episode: 368  step:  58
# Episode: 369  step:  68
# Episode: 370  step:  56
# Episode: 371  step:  54
# Loss:  5.51516
# Episode: 372  step:  74
# Episode: 373  step:  50
# Episode: 374  step:  38
# Episode: 375  step:  43
# Episode: 376  step:  38
# Episode: 377  step:  41
# Episode: 378  step:  42
# Episode: 379  step:  31
# Episode: 380  step:  57
# Episode: 381  step:  45
# Loss:  452.338
# Episode: 382  step:  48
# Episode: 383  step:  46
# Episode: 384  step:  50
# Episode: 385  step:  59
# Episode: 386  step:  46
# Episode: 387  step:  52
# Episode: 388  step:  88
# Episode: 389  step:  57
# Episode: 390  step:  85
# Episode: 391  step:  46
# Loss:  531.797
# Episode: 392  step:  30
# Episode: 393  step:  73
# Episode: 394  step:  35
# Episode: 395  step:  28
# Episode: 396  step:  45
# Episode: 397  step:  23
# Episode: 398  step:  25
# Episode: 399  step:  121
# Episode: 400  step:  87
# Episode: 401  step:  28
# Loss:  7.95466
# Episode: 402  step:  25
# Episode: 403  step:  50
# Episode: 404  step:  22
# Episode: 405  step:  22
# Episode: 406  step:  27
# Episode: 407  step:  21
# Episode: 408  step:  66
# Episode: 409  step:  19
# Episode: 410  step:  26
# Episode: 411  step:  68
# Loss:  3.4119
# Episode: 412  step:  33
# Episode: 413  step:  47
# Episode: 414  step:  41
# Episode: 415  step:  50
# Episode: 416  step:  33
# Episode: 417  step:  26
# Episode: 418  step:  55
# Episode: 419  step:  37
# Episode: 420  step:  39
# Episode: 421  step:  31
# Loss:  3.08037
# Episode: 422  step:  9
# Episode: 423  step:  10
# Episode: 424  step:  10
# Episode: 425  step:  9
# Episode: 426  step:  11
# Episode: 427  step:  9
# Episode: 428  step:  9
# Episode: 429  step:  10
# Episode: 430  step:  10
# Episode: 431  step:  8
# Loss:  1.46046
# Episode: 432  step:  36
# Episode: 433  step:  43
# Episode: 434  step:  38
# Episode: 435  step:  34
# Episode: 436  step:  29
# Episode: 437  step:  31
# Episode: 438  step:  52
# Episode: 439  step:  39
# Episode: 440  step:  30
# Episode: 441  step:  70
# Loss:  1.27412
# Episode: 442  step:  50
# Episode: 443  step:  22
# Episode: 444  step:  37
# Episode: 445  step:  27
# Episode: 446  step:  24
# Episode: 447  step:  30
# Episode: 448  step:  20
# Episode: 449  step:  27
# Episode: 450  step:  41
# Episode: 451  step:  77
# Loss:  5.33843
# Episode: 452  step:  10
# Episode: 453  step:  9
# Episode: 454  step:  9
# Episode: 455  step:  10
# Episode: 456  step:  9
# Episode: 457  step:  9
# Episode: 458  step:  8
# Episode: 459  step:  10
# Episode: 460  step:  8
# Episode: 461  step:  9
# Loss:  2.43926
# Episode: 462  step:  16
# Episode: 463  step:  16
# Episode: 464  step:  16
# Episode: 465  step:  49
# Episode: 466  step:  31
# Episode: 467  step:  42
# Episode: 468  step:  19
# Episode: 469  step:  24
# Episode: 470  step:  18
# Episode: 471  step:  17
# Loss:  9.63674
# Episode: 472  step:  11
# Episode: 473  step:  12
# Episode: 474  step:  14
# Episode: 475  step:  12
# Episode: 476  step:  14
# Episode: 477  step:  13
# Episode: 478  step:  22
# Episode: 479  step:  24
# Episode: 480  step:  14
# Episode: 481  step:  15
# Loss:  10.5317
# Episode: 482  step:  20
# Episode: 483  step:  68
# Episode: 484  step:  36
# Episode: 485  step:  39
# Episode: 486  step:  20
# Episode: 487  step:  24
# Episode: 488  step:  19
# Episode: 489  step:  20
# Episode: 490  step:  22
# Episode: 491  step:  19
# Loss:  477.737
# Episode: 492  step:  54
# Episode: 493  step:  29
# Episode: 494  step:  29
# Episode: 495  step:  31
# Episode: 496  step:  49
# Episode: 497  step:  31
# Episode: 498  step:  27
# Episode: 499  step:  38
# Episode: 500  step:  77
# Episode: 501  step:  68
# Loss:  6.83809
# Episode: 502  step:  22
# Episode: 503  step:  22
# Episode: 504  step:  19
# Episode: 505  step:  18
# Episode: 506  step:  15
# Episode: 507  step:  17
# Episode: 508  step:  18
# Episode: 509  step:  22
# Episode: 510  step:  29
# Episode: 511  step:  36
# Loss:  1.34057
# Episode: 512  step:  31
# Episode: 513  step:  30
# Episode: 514  step:  27
# Episode: 515  step:  21
# Episode: 516  step:  27
# Episode: 517  step:  27
# Episode: 518  step:  44
# Episode: 519  step:  66
# Episode: 520  step:  25
# Episode: 521  step:  26
# Loss:  3.22051
# Episode: 522  step:  53
# Episode: 523  step:  29
# Episode: 524  step:  26
# Episode: 525  step:  31
# Episode: 526  step:  42
# Episode: 527  step:  26
# Episode: 528  step:  45
# Episode: 529  step:  39
# Episode: 530  step:  39
# Episode: 531  step:  46
# Loss:  5.36231
# Episode: 532  step:  22
# Episode: 533  step:  34
# Episode: 534  step:  56
# Episode: 535  step:  22
# Episode: 536  step:  22
# Episode: 537  step:  36
# Episode: 538  step:  34
# Episode: 539  step:  76
# Episode: 540  step:  31
# Episode: 541  step:  23
# Loss:  3.03784
# Episode: 542  step:  21
# Episode: 543  step:  24
# Episode: 544  step:  22
# Episode: 545  step:  44
# Episode: 546  step:  63
# Episode: 547  step:  33
# Episode: 548  step:  21
# Episode: 549  step:  33
# Episode: 550  step:  24
# Episode: 551  step:  22
# Loss:  4.99018
# Episode: 552  step:  33
# Episode: 553  step:  28
# Episode: 554  step:  24
# Episode: 555  step:  28
# Episode: 556  step:  51
# Episode: 557  step:  37
# Episode: 558  step:  45
# Episode: 559  step:  69
# Episode: 560  step:  36
# Episode: 561  step:  26
# Loss:  3.04616
# Episode: 562  step:  25
# Episode: 563  step:  75
# Episode: 564  step:  55
# Episode: 565  step:  33
# Episode: 566  step:  26
# Episode: 567  step:  44
# Episode: 568  step:  45
# Episode: 569  step:  30
# Episode: 570  step:  23
# Episode: 571  step:  38
# Loss:  2.21329
# Episode: 572  step:  38
# Episode: 573  step:  33
# Episode: 574  step:  43
# Episode: 575  step:  35
# Episode: 576  step:  33
# Episode: 577  step:  47
# Episode: 578  step:  93
# Episode: 579  step:  69
# Episode: 580  step:  48
# Episode: 581  step:  31
# Loss:  4.841
# Episode: 582  step:  10
# Episode: 583  step:  15
# Episode: 584  step:  10
# Episode: 585  step:  16
# Episode: 586  step:  12
# Episode: 587  step:  14
# Episode: 588  step:  15
# Episode: 589  step:  27
# Episode: 590  step:  22
# Episode: 591  step:  16
# Loss:  3.56199
# Episode: 592  step:  60
# Episode: 593  step:  58
# Episode: 594  step:  52
# Episode: 595  step:  200
# Episode: 596  step:  117
# Episode: 597  step:  200
# Episode: 598  step:  55
# Episode: 599  step:  45
# Episode: 600  step:  69
# Episode: 601  step:  66
# Loss:  9.20058
# Episode: 602  step:  22
# Episode: 603  step:  21
# Episode: 604  step:  21
# Episode: 605  step:  25
# Episode: 606  step:  20
# Episode: 607  step:  28
# Episode: 608  step:  25
# Episode: 609  step:  60
# Episode: 610  step:  22
# Episode: 611  step:  31
# Loss:  5.99843
# Episode: 612  step:  25
# Episode: 613  step:  21
# Episode: 614  step:  32
# Episode: 615  step:  22
# Episode: 616  step:  13
# Episode: 617  step:  26
# Episode: 618  step:  24
# Episode: 619  step:  31
# Episode: 620  step:  38
# Episode: 621  step:  20
# Loss:  8.36999
# Episode: 622  step:  55
# Episode: 623  step:  32
# Episode: 624  step:  22
# Episode: 625  step:  31
# Episode: 626  step:  56
# Episode: 627  step:  26
# Episode: 628  step:  28
# Episode: 629  step:  30
# Episode: 630  step:  76
# Episode: 631  step:  23
# Loss:  457.925
# Episode: 632  step:  28
# Episode: 633  step:  24
# Episode: 634  step:  44
# Episode: 635  step:  23
# Episode: 636  step:  54
# Episode: 637  step:  33
# Episode: 638  step:  25
# Episode: 639  step:  30
# Episode: 640  step:  30
# Episode: 641  step:  35

# %%
bot_play(mainDQN)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-26fc050f602a> in <module>()
# ----> 1 bot_play(mainDQN)
#
# <ipython-input-5-43c8137ce628> in bot_play(mainDQN)
#       5     while True:
#       6         env.render()
# ----> 7         a = np.argmax(mainDQN.predict(s))
#       8         s, reward, done, _ = env.step(a)
#       9         reward_sum += reward
#
# AttributeError: 'NoneType' object has no attribute 'predict'
